# %%
from src.config import BASE_DIR

# %%
print(BASE_DIR)
# Out:
# /Users/marco/Work-MBP/railways_resilience

# %%
from src.functions.v0 import load_graph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from src.functions.v0 import load_graph
#
# File ~/Work-MBP/railways_resilience/src/functions/v0.py:1
# ----> 1 import pandas as pd
#       2 import os
#       3 from itertools import islice
#
# ModuleNotFoundError: No module named 'pandas'
